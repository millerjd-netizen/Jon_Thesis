# %%
"""
MFC Model-Predictive Control - Correct Dosage
==============================================
- Calculates the EXACT dose volume needed using CSTR physics
- Doses ONE substrate at a time
- Evaluates every 1 minute
- Priority: pH > TAN > EC
"""

import numpy as np

# =============================================================================
# SYSTEM PARAMETERS
# =============================================================================

V_INITIAL = 1000.0
DT = 1.0  # 1 minute

MIN_DOSE_ML = 0.5   # Minimum practical dose
MAX_DOSE_ML = 50.0  # Maximum single dose

# =============================================================================
# TARGETS (same as bang-bang for fair comparison)
# =============================================================================

TARGETS = {
    'pH':  {'min': 6.8, 'max': 7.2, 'setpoint': 7.0},
    'EC':  {'min': 5.0, 'max': 10.0, 'setpoint': 7.5},
    'TAN': {'min': 50.0, 'max': 200.0, 'setpoint': 125.0}
}

METAL_TARGETS = {
    'Fe': (1.0, 10.0), 'Zn': (0.1, 1.0), 'Cu': (0.01, 0.5),
    'Mn': (0.1, 1.0), 'Se': (0.01, 0.1), 'Ni': (0.05, 1.0), 'Co': (0.01, 0.3)
}

# =============================================================================
# DRIFT MODEL (same as bang-bang)
# =============================================================================

A_MATRIX = np.diag([-0.0001, -0.0001, -0.00003])
DRIFT = np.array([-0.0005, -0.001, -0.3])
METAL_DECAY_RATE = 0.0005

# =============================================================================
# SUBSTRATES (same as bang-bang)
# =============================================================================

SUBSTRATES = {
    'wine': {
        'pH': 4.0, 'EC': 0.02, 'TAN': 0.1,
        'Fe': 0.05, 'Zn': 0.01, 'Cu': 0.001, 'Mn': 0.02,
        'Se': 0.0, 'Ni': 0.0, 'Co': 0.0
    },
    'urine': {
        'pH': 8.5, 'EC': 6.25, 'TAN': 200.0,
        'Fe': 0.01, 'Zn': 0.05, 'Cu': 0.01, 'Mn': 0.005,
        'Se': 0.001, 'Ni': 0.002, 'Co': 0.001
    },
    'spirulina': {
        'pH': 9.0, 'EC': 1.14, 'TAN': 144.0,
        'Fe': 4.275, 'Zn': 0.300, 'Cu': 0.915, 'Mn': 0.285,
        'Se': 0.00105, 'Ni': 0.0, 'Co': 0.0
    }
}

# =============================================================================
# PHYSICS: CSTR MIXING EQUATION
# =============================================================================

def calculate_dose_to_target(current, target, substrate_val, volume):
    """
    Calculate exact dose volume to reach target using CSTR mixing.

    CSTR mixing: x_new = (x_current * V + x_substrate * V_dose) / (V + V_dose)

    Solving for V_dose:
        x_new * (V + V_dose) = x_current * V + x_substrate * V_dose
        x_new * V + x_new * V_dose = x_current * V + x_substrate * V_dose
        x_new * V - x_current * V = x_substrate * V_dose - x_new * V_dose
        V * (x_new - x_current) = V_dose * (x_substrate - x_new)
        V_dose = V * (x_target - x_current) / (x_substrate - x_target)
    """
    # Check if substrate can move us toward target
    if abs(substrate_val - current) < 1e-9:
        return 0  # Substrate same as current, can't help

    need_increase = (target > current)
    substrate_higher = (substrate_val > current)

    if need_increase != substrate_higher:
        return 0  # Wrong substrate - would move us away from target

    denom = substrate_val - target
    if abs(denom) < 1e-9:
        return MAX_DOSE_ML  # Substrate equals target, need infinite

    dose = volume * (target - current) / denom

    # Clamp to valid range
    if dose < MIN_DOSE_ML:
        return 0
    return min(dose, MAX_DOSE_ML)


def apply_dose(state, volume, substrate_name, dose_ml):
    """Apply CSTR mixing for a dose"""
    substrate = SUBSTRATES[substrate_name]
    new_vol = volume + dose_ml

    new_state = {}
    for key in state:
        if key in substrate:
            new_state[key] = (state[key] * volume + substrate[key] * dose_ml) / new_vol
        else:
            new_state[key] = state[key]

    return new_state, new_vol


def apply_drift(state, dt):
    """Apply autonomous dynamics (same as bang-bang)"""
    x = np.array([state['pH'], state['EC'], state['TAN']])
    dx_dt = A_MATRIX @ x + DRIFT
    x_new = x + dx_dt * dt

    decay = np.exp(-METAL_DECAY_RATE * dt)

    return {
        'pH': max(0, x_new[0]),
        'EC': max(0.01, x_new[1]),
        'TAN': max(0, x_new[2]),
        'Fe': state['Fe'] * decay,
        'Zn': state['Zn'] * decay,
        'Cu': state['Cu'] * decay,
        'Mn': state['Mn'] * decay,
        'Se': state['Se'] * decay,
        'Ni': state['Ni'] * decay,
        'Co': state['Co'] * decay,
    }

# =============================================================================
# MPC CONTROLLER - ONE SUBSTRATE AT A TIME
# =============================================================================

def mpc_control_decision(state, volume):
    """
    Physics-based control decision.

    Same priority as bang-bang:
    1. pH (highest) - bacterial survival
    2. TAN - nitrogen for growth
    3. EC - affects power output

    BUT: calculates exact dose volume to reach SETPOINT, not fixed 5mL

    Returns: (substrate_name or None, dose_ml, reason)
    """
    pH = state['pH']
    EC = state['EC']
    TAN = state['TAN']

    # === PRIORITY 1: pH control ===
    if pH > TARGETS['pH']['max']:
        # pH too high - need wine (acidic) to lower it
        dose = calculate_dose_to_target(pH, TARGETS['pH']['setpoint'],
                                        SUBSTRATES['wine']['pH'], volume)
        if dose >= MIN_DOSE_ML:
            return 'wine', dose, f"pH HIGH ({pH:.2f}>{TARGETS['pH']['max']}) -> dose to {TARGETS['pH']['setpoint']}"

    if pH < TARGETS['pH']['min']:
        # pH too low - need urine (basic) to raise it
        dose = calculate_dose_to_target(pH, TARGETS['pH']['setpoint'],
                                        SUBSTRATES['urine']['pH'], volume)
        if dose >= MIN_DOSE_ML:
            return 'urine', dose, f"pH LOW ({pH:.2f}<{TARGETS['pH']['min']}) -> dose to {TARGETS['pH']['setpoint']}"

    # === PRIORITY 2 & 3: TAN and EC combined logic (same as bang-bang) ===
    if TAN < TARGETS['TAN']['min'] and EC < TARGETS['EC']['min']:
        # Both low - urine provides both TAN and EC
        # Calculate dose for TAN (limiting factor usually)
        dose = calculate_dose_to_target(TAN, TARGETS['TAN']['setpoint'],
                                        SUBSTRATES['urine']['TAN'], volume)
        if dose >= MIN_DOSE_ML:
            return 'urine', dose, f"TAN+EC LOW (TAN={TAN:.1f}, EC={EC:.2f}) -> urine to TAN={TARGETS['TAN']['setpoint']}"

    if TAN < TARGETS['TAN']['min']:
        # TAN low, EC is OK - use spirulina (provides TAN without much EC change)
        dose = calculate_dose_to_target(TAN, TARGETS['TAN']['setpoint'],
                                        SUBSTRATES['spirulina']['TAN'], volume)
        if dose >= MIN_DOSE_ML:
            return 'spirulina', dose, f"TAN LOW ({TAN:.1f}<{TARGETS['TAN']['min']}) -> spirulina to {TARGETS['TAN']['setpoint']}"

    if EC < TARGETS['EC']['min']:
        # EC low, TAN is OK - use urine for EC
        dose = calculate_dose_to_target(EC, TARGETS['EC']['setpoint'],
                                        SUBSTRATES['urine']['EC'], volume)
        if dose >= MIN_DOSE_ML:
            return 'urine', dose, f"EC LOW ({EC:.2f}<{TARGETS['EC']['min']}) -> urine to EC={TARGETS['EC']['setpoint']}"

    # All in range
    return None, 0, "All parameters in range"

# =============================================================================
# SIMULATION
# =============================================================================

def run_simulation(duration_minutes=480, initial_state=None):
    if initial_state is None:
        initial_state = {
            'pH': 7.0, 'EC': 5.5, 'TAN': 80.0,
            'Fe': 1.0, 'Zn': 0.1, 'Cu': 0.05, 'Mn': 0.1,
            'Se': 0.01, 'Ni': 0.01, 'Co': 0.01
        }

    state = initial_state.copy()
    volume = V_INITIAL
    history = []

    total_volumes = {'wine': 0.0, 'urine': 0.0, 'spirulina': 0.0}
    dose_counts = {'wine': 0, 'urine': 0, 'spirulina': 0}
    dose_events = []

    print("=" * 140)
    print("MFC MODEL-PREDICTIVE CONTROL - PHYSICS-BASED DOSING")
    print("Calculates exact dose to reach setpoint | One substrate at a time | Every 1 minute")
    print("=" * 140)
    print(f"\nTargets: pH [{TARGETS['pH']['min']}-{TARGETS['pH']['max']}] setpoint={TARGETS['pH']['setpoint']}")
    print(f"         EC [{TARGETS['EC']['min']}-{TARGETS['EC']['max']}] setpoint={TARGETS['EC']['setpoint']} mS/cm")
    print(f"         TAN [{TARGETS['TAN']['min']}-{TARGETS['TAN']['max']}] setpoint={TARGETS['TAN']['setpoint']} mg-N/L")
    print(f"\nDose range: {MIN_DOSE_ML}-{MAX_DOSE_ML} mL")
    print("\n" + "=" * 140)
    print(f"\n{'Time':<6} {'pH':>6} {'EC':>8} {'TAN':>8} {'Vol':>8} {'Action':<60} {'Dose':>10}")
    print(f"{'(min)':<6} {'':>6} {'(mS/cm)':>8} {'(mg-N/L)':>8} {'(mL)':>8} {'':<60} {'(mL)':>10}")
    print("-" * 140)

    for t in range(int(duration_minutes) + 1):
        history.append({'time': t, 'volume': volume, **state.copy()})

        # MPC control decision
        action, dose_ml, reason = mpc_control_decision(state, volume)

        if action:
            action_str = f"DOSE {action.upper()}: {reason}"
            dose_str = f"{dose_ml:.1f}"
        else:
            action_str = reason
            dose_str = "---"

        # Print every line (every minute)
        print(f"{t:<6} {state['pH']:>6.2f} {state['EC']:>8.2f} {state['TAN']:>8.1f} "
              f"{volume:>8.0f} {action_str:<60} {dose_str:>10}")

        # Execute dose
        if action and dose_ml >= MIN_DOSE_ML:
            state, volume = apply_dose(state, volume, action, dose_ml)
            dose_counts[action] += 1
            total_volumes[action] += dose_ml
            dose_events.append({
                'time': t,
                'substrate': action,
                'volume_ml': dose_ml,
                'reason': reason
            })

        # Apply drift for next step
        if t < duration_minutes:
            state = apply_drift(state, DT)

    # Summary
    print("-" * 140)
    print("\n" + "=" * 140)
    print("SIMULATION SUMMARY")
    print("=" * 140)

    total_dosed = sum(total_volumes.values())
    print(f"\nDuration: {duration_minutes} minutes ({duration_minutes/60:.1f} hours)")
    print(f"Final Volume: {volume:.0f} mL")

    print(f"\nSubstrate Usage:")
    for sub in ['wine', 'urine', 'spirulina']:
        pct = (total_volumes[sub] / total_dosed * 100) if total_dosed > 0 else 0
        avg_dose = total_volumes[sub] / dose_counts[sub] if dose_counts[sub] > 0 else 0
        print(f"  {sub.capitalize():<12}: {total_volumes[sub]:>8.1f} mL ({pct:>5.1f}%) - {dose_counts[sub]:>3} doses (avg {avg_dose:.1f} mL/dose)")
    print(f"  {'Total':<12}: {total_dosed:>8.1f} mL - {sum(dose_counts.values())} doses")

    print(f"\nFinal State:")
    print(f"  pH:  {state['pH']:.2f} (target range: {TARGETS['pH']['min']}-{TARGETS['pH']['max']})")
    print(f"  EC:  {state['EC']:.2f} mS/cm (target range: {TARGETS['EC']['min']}-{TARGETS['EC']['max']})")
    print(f"  TAN: {state['TAN']:.1f} mg-N/L (target range: {TARGETS['TAN']['min']}-{TARGETS['TAN']['max']})")

    # Range compliance
    ph_ok = TARGETS['pH']['min'] <= state['pH'] <= TARGETS['pH']['max']
    ec_ok = TARGETS['EC']['min'] <= state['EC'] <= TARGETS['EC']['max']
    tan_ok = TARGETS['TAN']['min'] <= state['TAN'] <= TARGETS['TAN']['max']

    print(f"\nRange Compliance:")
    print(f"  pH:  {'✓ IN RANGE' if ph_ok else '✗ OUT OF RANGE'}")
    print(f"  EC:  {'✓ IN RANGE' if ec_ok else '✗ OUT OF RANGE'}")
    print(f"  TAN: {'✓ IN RANGE' if tan_ok else '✗ OUT OF RANGE'}")

    print(f"\nFinal Trace Metals:")
    for metal, (lo, hi) in METAL_TARGETS.items():
        val = state[metal]
        status = "OK" if lo <= val <= hi else ("LOW" if val < lo else "HIGH")
        print(f"  {metal}: {val:.4f} mg/L (target: {lo}-{hi}) {status}")

    # Comparison with bang-bang
    print(f"\n" + "=" * 140)
    print("COMPARISON: MPC vs BANG-BANG (fixed 5mL)")
    print("=" * 140)
    bb_doses = 333
    bb_volume = 1665
    print(f"  {'Metric':<25} {'MPC':>15} {'Bang-Bang':>15} {'Difference':>15}")
    print(f"  {'-'*25} {'-'*15} {'-'*15} {'-'*15}")
    print(f"  {'Total doses':<25} {sum(dose_counts.values()):>15} {bb_doses:>15} {sum(dose_counts.values())-bb_doses:>+15}")
    print(f"  {'Total volume (mL)':<25} {total_dosed:>15.1f} {bb_volume:>15} {total_dosed-bb_volume:>+15.1f}")
    if sum(dose_counts.values()) > 0:
        print(f"  {'Avg dose size (mL)':<25} {total_dosed/sum(dose_counts.values()):>15.1f} {5.0:>15.1f} {'':>15}")

    return history, dose_events


if __name__ == "__main__":
    history, events = run_simulation(duration_minutes=480)
# Out:
# ============================================================================================================================================
# MFC MODEL-PREDICTIVE CONTROL - PHYSICS-BASED DOSING
# Calculates exact dose to reach setpoint | One substrate at a time | Every 1 minute
# ============================================================================================================================================
#
# Targets: pH [6.8-7.2] setpoint=7.0
#          EC [5.0-10.0] setpoint=7.5 mS/cm
#          TAN [50.0-200.0] setpoint=125.0 mg-N/L
#
# Dose range: 0.5-50.0 mL
#
# ============================================================================================================================================
#
# Time       pH       EC      TAN      Vol Action                                                             Dose
# (min)          (mS/cm) (mg-N/L)     (mL)                                                                    (mL)
# --------------------------------------------------------------------------------------------------------------------------------------------
# 0        7.00     5.50     80.0     1000 All parameters in range                                             ---
# 1        7.00     5.50     79.7     1000 All parameters in range                                             ---
# 2        7.00     5.50     79.4     1000 All parameters in range                                             ---
# 3        7.00     5.50     79.1     1000 All parameters in range                                             ---
# 4        7.00     5.49     78.8     1000 All parameters in range                                             ---
# 5        6.99     5.49     78.5     1000 All parameters in range                                             ---
# 6        6.99     5.49     78.2     1000 All parameters in range                                             ---
# 7        6.99     5.49     77.9     1000 All parameters in range                                             ---
# 8        6.99     5.49     77.6     1000 All parameters in range                                             ---
# 9        6.99     5.49     77.3     1000 All parameters in range                                             ---
# 10       6.99     5.48     77.0     1000 All parameters in range                                             ---
# 11       6.99     5.48     76.7     1000 All parameters in range                                             ---
# 12       6.99     5.48     76.4     1000 All parameters in range                                             ---
# 13       6.98     5.48     76.1     1000 All parameters in range                                             ---
# 14       6.98     5.48     75.8     1000 All parameters in range                                             ---
# 15       6.98     5.48     75.5     1000 All parameters in range                                             ---
# 16       6.98     5.48     75.2     1000 All parameters in range                                             ---
# 17       6.98     5.47     74.9     1000 All parameters in range                                             ---
# 18       6.98     5.47     74.6     1000 All parameters in range                                             ---
# 19       6.98     5.47     74.3     1000 All parameters in range                                             ---
# 20       6.98     5.47     74.0     1000 All parameters in range                                             ---
# 21       6.97     5.47     73.7     1000 All parameters in range                                             ---
# 22       6.97     5.47     73.3     1000 All parameters in range                                             ---
# 23       6.97     5.46     73.0     1000 All parameters in range                                             ---
# 24       6.97     5.46     72.7     1000 All parameters in range                                             ---
# 25       6.97     5.46     72.4     1000 All parameters in range                                             ---
# 26       6.97     5.46     72.1     1000 All parameters in range                                             ---
# 27       6.97     5.46     71.8     1000 All parameters in range                                             ---
# 28       6.97     5.46     71.5     1000 All parameters in range                                             ---
# 29       6.97     5.46     71.2     1000 All parameters in range                                             ---
# 30       6.96     5.45     70.9     1000 All parameters in range                                             ---
# 31       6.96     5.45     70.6     1000 All parameters in range                                             ---
# 32       6.96     5.45     70.3     1000 All parameters in range                                             ---
# 33       6.96     5.45     70.0     1000 All parameters in range                                             ---
# 34       6.96     5.45     69.7     1000 All parameters in range                                             ---
# 35       6.96     5.45     69.4     1000 All parameters in range                                             ---
# 36       6.96     5.44     69.1     1000 All parameters in range                                             ---
# 37       6.96     5.44     68.8     1000 All parameters in range                                             ---
# 38       6.95     5.44     68.5     1000 All parameters in range                                             ---
# 39       6.95     5.44     68.2     1000 All parameters in range                                             ---
# 40       6.95     5.44     67.9     1000 All parameters in range                                             ---
# 41       6.95     5.44     67.6     1000 All parameters in range                                             ---
# 42       6.95     5.44     67.3     1000 All parameters in range                                             ---
# 43       6.95     5.43     67.0     1000 All parameters in range                                             ---
# 44       6.95     5.43     66.7     1000 All parameters in range                                             ---
# 45       6.95     5.43     66.4     1000 All parameters in range                                             ---
# 46       6.94     5.43     66.1     1000 All parameters in range                                             ---
# 47       6.94     5.43     65.8     1000 All parameters in range                                             ---
# 48       6.94     5.43     65.5     1000 All parameters in range                                             ---
# 49       6.94     5.42     65.2     1000 All parameters in range                                             ---
# 50       6.94     5.42     64.9     1000 All parameters in range                                             ---
# 51       6.94     5.42     64.6     1000 All parameters in range                                             ---
# 52       6.94     5.42     64.3     1000 All parameters in range                                             ---
# 53       6.94     5.42     64.0     1000 All parameters in range                                             ---
# 54       6.94     5.42     63.7     1000 All parameters in range                                             ---
# 55       6.93     5.41     63.4     1000 All parameters in range                                             ---
# 56       6.93     5.41     63.1     1000 All parameters in range                                             ---
# 57       6.93     5.41     62.8     1000 All parameters in range                                             ---
# 58       6.93     5.41     62.5     1000 All parameters in range                                             ---
# 59       6.93     5.41     62.2     1000 All parameters in range                                             ---
# 60       6.93     5.41     61.9     1000 All parameters in range                                             ---
# 61       6.93     5.41     61.6     1000 All parameters in range                                             ---
# 62       6.93     5.40     61.3     1000 All parameters in range                                             ---
# 63       6.92     5.40     61.0     1000 All parameters in range                                             ---
# 64       6.92     5.40     60.7     1000 All parameters in range                                             ---
# 65       6.92     5.40     60.4     1000 All parameters in range                                             ---
# 66       6.92     5.40     60.1     1000 All parameters in range                                             ---
# 67       6.92     5.40     59.8     1000 All parameters in range                                             ---
# 68       6.92     5.39     59.5     1000 All parameters in range                                             ---
# 69       6.92     5.39     59.2     1000 All parameters in range                                             ---
# 70       6.92     5.39     58.9     1000 All parameters in range                                             ---
# 71       6.92     5.39     58.6     1000 All parameters in range                                             ---
# 72       6.91     5.39     58.3     1000 All parameters in range                                             ---
# 73       6.91     5.39     57.9     1000 All parameters in range                                             ---
# 74       6.91     5.39     57.6     1000 All parameters in range                                             ---
# 75       6.91     5.38     57.3     1000 All parameters in range                                             ---
# 76       6.91     5.38     57.0     1000 All parameters in range                                             ---
# 77       6.91     5.38     56.7     1000 All parameters in range                                             ---
# 78       6.91     5.38     56.4     1000 All parameters in range                                             ---
# 79       6.91     5.38     56.1     1000 All parameters in range                                             ---
# 80       6.90     5.38     55.8     1000 All parameters in range                                             ---
# 81       6.90     5.37     55.5     1000 All parameters in range                                             ---
# 82       6.90     5.37     55.2     1000 All parameters in range                                             ---
# 83       6.90     5.37     54.9     1000 All parameters in range                                             ---
# 84       6.90     5.37     54.6     1000 All parameters in range                                             ---
# 85       6.90     5.37     54.3     1000 All parameters in range                                             ---
# 86       6.90     5.37     54.0     1000 All parameters in range                                             ---
# 87       6.90     5.37     53.7     1000 All parameters in range                                             ---
# 88       6.89     5.36     53.4     1000 All parameters in range                                             ---
# 89       6.89     5.36     53.1     1000 All parameters in range                                             ---
# 90       6.89     5.36     52.8     1000 All parameters in range                                             ---
# 91       6.89     5.36     52.5     1000 All parameters in range                                             ---
# 92       6.89     5.36     52.2     1000 All parameters in range                                             ---
# 93       6.89     5.36     51.9     1000 All parameters in range                                             ---
# 94       6.89     5.35     51.6     1000 All parameters in range                                             ---
# 95       6.89     5.35     51.3     1000 All parameters in range                                             ---
# 96       6.89     5.35     51.0     1000 All parameters in range                                             ---
# 97       6.88     5.35     50.7     1000 All parameters in range                                             ---
# 98       6.88     5.35     50.4     1000 All parameters in range                                             ---
# 99       6.88     5.35     50.1     1000 All parameters in range                                             ---
# 100      6.88     5.35     49.8     1000 DOSE SPIRULINA: TAN LOW (49.8<50.0) -> spirulina to 125.0          50.0
# 101      6.98     5.14     54.0     1050 All parameters in range                                             ---
# 102      6.98     5.14     53.7     1050 All parameters in range                                             ---
# 103      6.98     5.14     53.4     1050 All parameters in range                                             ---
# 104      6.98     5.14     53.1     1050 All parameters in range                                             ---
# 105      6.98     5.14     52.8     1050 All parameters in range                                             ---
# 106      6.97     5.14     52.5     1050 All parameters in range                                             ---
# 107      6.97     5.13     52.2     1050 All parameters in range                                             ---
# 108      6.97     5.13     51.9     1050 All parameters in range                                             ---
# 109      6.97     5.13     51.6     1050 All parameters in range                                             ---
# 110      6.97     5.13     51.3     1050 All parameters in range                                             ---
# 111      6.97     5.13     51.0     1050 All parameters in range                                             ---
# 112      6.97     5.13     50.7     1050 All parameters in range                                             ---
# 113      6.97     5.13     50.4     1050 All parameters in range                                             ---
# 114      6.96     5.12     50.1     1050 All parameters in range                                             ---
# 115      6.96     5.12     49.8     1050 DOSE SPIRULINA: TAN LOW (49.8<50.0) -> spirulina to 125.0          50.0
# 116      7.05     4.94     53.7     1100 All parameters in range                                             ---
# 117      7.05     4.94     53.4     1100 All parameters in range                                             ---
# 118      7.05     4.94     53.1     1100 All parameters in range                                             ---
# 119      7.05     4.94     52.8     1100 All parameters in range                                             ---
# 120      7.05     4.93     52.5     1100 All parameters in range                                             ---
# 121      7.05     4.93     52.2     1100 All parameters in range                                             ---
# 122      7.05     4.93     51.9     1100 All parameters in range                                             ---
# 123      7.05     4.93     51.6     1100 All parameters in range                                             ---
# 124      7.05     4.93     51.3     1100 All parameters in range                                             ---
# 125      7.04     4.93     51.0     1100 All parameters in range                                             ---
# 126      7.04     4.93     50.7     1100 All parameters in range                                             ---
# 127      7.04     4.92     50.4     1100 All parameters in range                                             ---
# 128      7.04     4.92     50.1     1100 All parameters in range                                             ---
# 129      7.04     4.92     49.8     1100 DOSE URINE: TAN+EC LOW (TAN=49.8, EC=4.92) -> urine to TAN=125.0       50.0
# 130      7.10     4.98     56.1     1150 All parameters in range                                             ---
# 131      7.10     4.98     55.8     1150 All parameters in range                                             ---
# 132      7.10     4.97     55.5     1150 All parameters in range                                             ---
# 133      7.10     4.97     55.2     1150 All parameters in range                                             ---
# 134      7.10     4.97     54.8     1150 All parameters in range                                             ---
# 135      7.10     4.97     54.5     1150 All parameters in range                                             ---
# 136      7.09     4.97     54.2     1150 All parameters in range                                             ---
# 137      7.09     4.97     53.9     1150 All parameters in range                                             ---
# 138      7.09     4.97     53.6     1150 All parameters in range                                             ---
# 139      7.09     4.96     53.3     1150 All parameters in range                                             ---
# 140      7.09     4.96     53.0     1150 All parameters in range                                             ---
# 141      7.09     4.96     52.7     1150 All parameters in range                                             ---
# 142      7.09     4.96     52.4     1150 All parameters in range                                             ---
# 143      7.09     4.96     52.1     1150 All parameters in range                                             ---
# 144      7.08     4.96     51.8     1150 All parameters in range                                             ---
# 145      7.08     4.95     51.5     1150 All parameters in range                                             ---
# 146      7.08     4.95     51.2     1150 All parameters in range                                             ---
# 147      7.08     4.95     50.9     1150 All parameters in range                                             ---
# 148      7.08     4.95     50.6     1150 All parameters in range                                             ---
# 149      7.08     4.95     50.3     1150 All parameters in range                                             ---
# 150      7.08     4.95     50.0     1150 All parameters in range                                             ---
# 151      7.08     4.95     49.7     1150 DOSE URINE: TAN+EC LOW (TAN=49.7, EC=4.95) -> urine to TAN=125.0       50.0
# 152      7.13     5.00     55.7     1200 All parameters in range                                             ---
# 153      7.13     5.00     55.4     1200 All parameters in range                                             ---
# 154      7.13     5.00     55.1     1200 All parameters in range                                             ---
# 155      7.13     4.99     54.8     1200 All parameters in range                                             ---
# 156      7.13     4.99     54.5     1200 All parameters in range                                             ---
# 157      7.13     4.99     54.2     1200 All parameters in range                                             ---
# 158      7.13     4.99     53.9     1200 All parameters in range                                             ---
# 159      7.13     4.99     53.6     1200 All parameters in range                                             ---
# 160      7.12     4.99     53.3     1200 All parameters in range                                             ---
# 161      7.12     4.99     53.0     1200 All parameters in range                                             ---
# 162      7.12     4.98     52.7     1200 All parameters in range                                             ---
# 163      7.12     4.98     52.4     1200 All parameters in range                                             ---
# 164      7.12     4.98     52.1     1200 All parameters in range                                             ---
# 165      7.12     4.98     51.8     1200 All parameters in range                                             ---
# 166      7.12     4.98     51.5     1200 All parameters in range                                             ---
# 167      7.12     4.98     51.2     1200 All parameters in range                                             ---
# 168      7.11     4.97     50.9     1200 All parameters in range                                             ---
# 169      7.11     4.97     50.6     1200 All parameters in range                                             ---
# 170      7.11     4.97     50.3     1200 All parameters in range                                             ---
# 171      7.11     4.97     50.0     1200 DOSE URINE: TAN+EC LOW (TAN=50.0, EC=4.97) -> urine to TAN=125.0       50.0
# 172      7.17     5.02     55.7     1250 All parameters in range                                             ---
# 173      7.16     5.02     55.4     1250 All parameters in range                                             ---
# 174      7.16     5.02     55.0     1250 All parameters in range                                             ---
# 175      7.16     5.02     54.7     1250 All parameters in range                                             ---
# 176      7.16     5.01     54.4     1250 All parameters in range                                             ---
# 177      7.16     5.01     54.1     1250 All parameters in range                                             ---
# 178      7.16     5.01     53.8     1250 All parameters in range                                             ---
# 179      7.16     5.01     53.5     1250 All parameters in range                                             ---
# 180      7.16     5.01     53.2     1250 All parameters in range                                             ---
# 181      7.15     5.01     52.9     1250 All parameters in range                                             ---
# 182      7.15     5.00     52.6     1250 All parameters in range                                             ---
# 183      7.15     5.00     52.3     1250 All parameters in range                                             ---
# 184      7.15     5.00     52.0     1250 All parameters in range                                             ---
# 185      7.15     5.00     51.7     1250 All parameters in range                                             ---
# 186      7.15     5.00     51.4     1250 All parameters in range                                             ---
# 187      7.15     5.00     51.1     1250 All parameters in range                                             ---
# 188      7.15     5.00     50.8     1250 All parameters in range                                             ---
# 189      7.14     4.99     50.5     1250 All parameters in range                                             ---
# 190      7.14     4.99     50.2     1250 All parameters in range                                             ---
# 191      7.14     4.99     49.9     1250 DOSE URINE: TAN+EC LOW (TAN=49.9, EC=4.99) -> urine to TAN=125.0       50.0
# 192      7.19     5.04     55.4     1300 All parameters in range                                             ---
# 193      7.19     5.04     55.1     1300 All parameters in range                                             ---
# 194      7.19     5.04     54.8     1300 All parameters in range                                             ---
# 195      7.19     5.03     54.5     1300 All parameters in range                                             ---
# 196      7.19     5.03     54.2     1300 All parameters in range                                             ---
# 197      7.19     5.03     53.9     1300 All parameters in range                                             ---
# 198      7.19     5.03     53.6     1300 All parameters in range                                             ---
# 199      7.18     5.03     53.3     1300 All parameters in range                                             ---
# 200      7.18     5.03     53.0     1300 All parameters in range                                             ---
# 201      7.18     5.02     52.7     1300 All parameters in range                                             ---
# 202      7.18     5.02     52.4     1300 All parameters in range                                             ---
# 203      7.18     5.02     52.1     1300 All parameters in range                                             ---
# 204      7.18     5.02     51.8     1300 All parameters in range                                             ---
# 205      7.18     5.02     51.5     1300 All parameters in range                                             ---
# 206      7.18     5.02     51.2     1300 All parameters in range                                             ---
# 207      7.18     5.02     50.9     1300 All parameters in range                                             ---
# 208      7.17     5.01     50.6     1300 All parameters in range                                             ---
# 209      7.17     5.01     50.3     1300 All parameters in range                                             ---
# 210      7.17     5.01     50.0     1300 DOSE SPIRULINA: TAN LOW (50.0<50.0) -> spirulina to 125.0          50.0
# 211      7.24     4.87     53.1     1350 DOSE WINE: pH HIGH (7.24>7.2) -> dose to 7.0                       50.0
# 212      7.12     4.69     50.9     1400 All parameters in range                                             ---
# 213      7.12     4.69     50.6     1400 All parameters in range                                             ---
# 214      7.12     4.69     50.3     1400 All parameters in range                                             ---
# 215      7.12     4.69     50.0     1400 All parameters in range                                             ---
# 216      7.12     4.69     49.7     1400 DOSE URINE: TAN+EC LOW (TAN=49.7, EC=4.69) -> urine to TAN=125.0       50.0
# 217      7.16     4.74     54.6     1450 All parameters in range                                             ---
# 218      7.16     4.74     54.3     1450 All parameters in range                                             ---
# 219      7.16     4.74     54.0     1450 All parameters in range                                             ---
# 220      7.16     4.73     53.7     1450 All parameters in range                                             ---
# 221      7.16     4.73     53.4     1450 All parameters in range                                             ---
# 222      7.16     4.73     53.1     1450 All parameters in range                                             ---
# 223      7.16     4.73     52.8     1450 All parameters in range                                             ---
# 224      7.15     4.73     52.5     1450 All parameters in range                                             ---
# 225      7.15     4.73     52.2     1450 All parameters in range                                             ---
# 226      7.15     4.73     51.9     1450 All parameters in range                                             ---
# 227      7.15     4.72     51.6     1450 All parameters in range                                             ---
# 228      7.15     4.72     51.3     1450 All parameters in range                                             ---
# 229      7.15     4.72     51.0     1450 All parameters in range                                             ---
# 230      7.15     4.72     50.7     1450 All parameters in range                                             ---
# 231      7.15     4.72     50.4     1450 All parameters in range                                             ---
# 232      7.14     4.72     50.1     1450 All parameters in range                                             ---
# 233      7.14     4.71     49.8     1450 DOSE URINE: TAN+EC LOW (TAN=49.8, EC=4.71) -> urine to TAN=125.0       50.0
# 234      7.19     4.76     54.5     1500 All parameters in range                                             ---
# 235      7.19     4.76     54.2     1500 All parameters in range                                             ---
# 236      7.18     4.76     53.9     1500 All parameters in range                                             ---
# 237      7.18     4.76     53.6     1500 All parameters in range                                             ---
# 238      7.18     4.76     53.3     1500 All parameters in range                                             ---
# 239      7.18     4.76     53.0     1500 All parameters in range                                             ---
# 240      7.18     4.76     52.7     1500 All parameters in range                                             ---
# 241      7.18     4.75     52.4     1500 All parameters in range                                             ---
# 242      7.18     4.75     52.1     1500 All parameters in range                                             ---
# 243      7.18     4.75     51.8     1500 All parameters in range                                             ---
# 244      7.18     4.75     51.5     1500 All parameters in range                                             ---
# 245      7.17     4.75     51.2     1500 All parameters in range                                             ---
# 246      7.17     4.75     50.9     1500 All parameters in range                                             ---
# 247      7.17     4.75     50.6     1500 All parameters in range                                             ---
# 248      7.17     4.74     50.3     1500 All parameters in range                                             ---
# 249      7.17     4.74     50.0     1500 DOSE URINE: TAN+EC LOW (TAN=50.0, EC=4.74) -> urine to TAN=125.0       50.0
# 250      7.21     4.79     54.5     1550 DOSE WINE: pH HIGH (7.21>7.2) -> dose to 7.0                       50.0
# 251      7.11     4.64     52.5     1600 All parameters in range                                             ---
# 252      7.11     4.64     52.2     1600 All parameters in range                                             ---
# 253      7.11     4.64     51.9     1600 All parameters in range                                             ---
# 254      7.11     4.63     51.6     1600 All parameters in range                                             ---
# 255      7.10     4.63     51.3     1600 All parameters in range                                             ---
# 256      7.10     4.63     51.0     1600 All parameters in range                                             ---
# 257      7.10     4.63     50.7     1600 All parameters in range                                             ---
# 258      7.10     4.63     50.4     1600 All parameters in range                                             ---
# 259      7.10     4.63     50.1     1600 All parameters in range                                             ---
# 260      7.10     4.63     49.8     1600 DOSE URINE: TAN+EC LOW (TAN=49.8, EC=4.63) -> urine to TAN=125.0       50.0
# 261      7.14     4.67     54.1     1650 All parameters in range                                             ---
# 262      7.14     4.67     53.7     1650 All parameters in range                                             ---
# 263      7.14     4.67     53.4     1650 All parameters in range                                             ---
# 264      7.14     4.67     53.1     1650 All parameters in range                                             ---
# 265      7.13     4.67     52.8     1650 All parameters in range                                             ---
# 266      7.13     4.67     52.5     1650 All parameters in range                                             ---
# 267      7.13     4.66     52.2     1650 All parameters in range                                             ---
# 268      7.13     4.66     51.9     1650 All parameters in range                                             ---
# 269      7.13     4.66     51.6     1650 All parameters in range                                             ---
# 270      7.13     4.66     51.3     1650 All parameters in range                                             ---
# 271      7.13     4.66     51.0     1650 All parameters in range                                             ---
# 272      7.13     4.66     50.7     1650 All parameters in range                                             ---
# 273      7.13     4.66     50.4     1650 All parameters in range                                             ---
# 274      7.12     4.65     50.1     1650 All parameters in range                                             ---
# 275      7.12     4.65     49.8     1650 DOSE URINE: TAN+EC LOW (TAN=49.8, EC=4.65) -> urine to TAN=125.0       50.0
# 276      7.16     4.70     53.9     1700 All parameters in range                                             ---
# 277      7.16     4.70     53.6     1700 All parameters in range                                             ---
# 278      7.16     4.70     53.3     1700 All parameters in range                                             ---
# 279      7.16     4.69     53.0     1700 All parameters in range                                             ---
# 280      7.16     4.69     52.7     1700 All parameters in range                                             ---
# 281      7.16     4.69     52.4     1700 All parameters in range                                             ---
# 282      7.15     4.69     52.1     1700 All parameters in range                                             ---
# 283      7.15     4.69     51.8     1700 All parameters in range                                             ---
# 284      7.15     4.69     51.5     1700 All parameters in range                                             ---
# 285      7.15     4.69     51.2     1700 All parameters in range                                             ---
# 286      7.15     4.68     50.9     1700 All parameters in range                                             ---
# 287      7.15     4.68     50.6     1700 All parameters in range                                             ---
# 288      7.15     4.68     50.3     1700 All parameters in range                                             ---
# 289      7.15     4.68     50.0     1700 All parameters in range                                             ---
# 290      7.14     4.68     49.7     1700 DOSE URINE: TAN+EC LOW (TAN=49.7, EC=4.68) -> urine to TAN=125.0       50.0
# 291      7.18     4.72     53.7     1750 All parameters in range                                             ---
# 292      7.18     4.72     53.4     1750 All parameters in range                                             ---
# 293      7.18     4.72     53.1     1750 All parameters in range                                             ---
# 294      7.18     4.72     52.8     1750 All parameters in range                                             ---
# 295      7.18     4.72     52.5     1750 All parameters in range                                             ---
# 296      7.18     4.71     52.2     1750 All parameters in range                                             ---
# 297      7.18     4.71     51.9     1750 All parameters in range                                             ---
# 298      7.17     4.71     51.6     1750 All parameters in range                                             ---
# 299      7.17     4.71     51.3     1750 All parameters in range                                             ---
# 300      7.17     4.71     51.0     1750 All parameters in range                                             ---
# 301      7.17     4.71     50.7     1750 All parameters in range                                             ---
# 302      7.17     4.71     50.4     1750 All parameters in range                                             ---
# 303      7.17     4.70     50.1     1750 All parameters in range                                             ---
# 304      7.17     4.70     49.8     1750 DOSE URINE: TAN+EC LOW (TAN=49.8, EC=4.70) -> urine to TAN=125.0       50.0
# 305      7.20     4.74     53.7     1800 DOSE WINE: pH HIGH (7.20>7.2) -> dose to 7.0                       50.0
# 306      7.11     4.61     51.9     1850 All parameters in range                                             ---
# 307      7.11     4.61     51.6     1850 All parameters in range                                             ---
# 308      7.11     4.61     51.3     1850 All parameters in range                                             ---
# 309      7.11     4.61     51.0     1850 All parameters in range                                             ---
# 310      7.11     4.61     50.7     1850 All parameters in range                                             ---
# 311      7.11     4.61     50.4     1850 All parameters in range                                             ---
# 312      7.11     4.61     50.1     1850 All parameters in range                                             ---
# 313      7.11     4.60     49.8     1850 DOSE URINE: TAN+EC LOW (TAN=49.8, EC=4.60) -> urine to TAN=125.0       50.0
# 314      7.14     4.65     53.5     1900 All parameters in range                                             ---
# 315      7.14     4.64     53.2     1900 All parameters in range                                             ---
# 316      7.14     4.64     52.9     1900 All parameters in range                                             ---
# 317      7.14     4.64     52.6     1900 All parameters in range                                             ---
# 318      7.14     4.64     52.2     1900 All parameters in range                                             ---
# 319      7.14     4.64     51.9     1900 All parameters in range                                             ---
# 320      7.13     4.64     51.6     1900 All parameters in range                                             ---
# 321      7.13     4.64     51.3     1900 All parameters in range                                             ---
# 322      7.13     4.63     51.0     1900 All parameters in range                                             ---
# 323      7.13     4.63     50.7     1900 All parameters in range                                             ---
# 324      7.13     4.63     50.4     1900 All parameters in range                                             ---
# 325      7.13     4.63     50.1     1900 All parameters in range                                             ---
# 326      7.13     4.63     49.8     1900 DOSE URINE: TAN+EC LOW (TAN=49.8, EC=4.63) -> urine to TAN=125.0       50.0
# 327      7.16     4.67     53.4     1950 All parameters in range                                             ---
# 328      7.16     4.67     53.1     1950 All parameters in range                                             ---
# 329      7.16     4.67     52.8     1950 All parameters in range                                             ---
# 330      7.16     4.66     52.5     1950 All parameters in range                                             ---
# 331      7.16     4.66     52.2     1950 All parameters in range                                             ---
# 332      7.15     4.66     51.9     1950 All parameters in range                                             ---
# 333      7.15     4.66     51.6     1950 All parameters in range                                             ---
# 334      7.15     4.66     51.3     1950 All parameters in range                                             ---
# 335      7.15     4.66     51.0     1950 All parameters in range                                             ---
# 336      7.15     4.66     50.7     1950 All parameters in range                                             ---
# 337      7.15     4.65     50.4     1950 All parameters in range                                             ---
# 338      7.15     4.65     50.1     1950 All parameters in range                                             ---
# 339      7.15     4.65     49.8     1950 DOSE URINE: TAN+EC LOW (TAN=49.8, EC=4.65) -> urine to TAN=125.0       50.0
# 340      7.18     4.69     53.2     2000 All parameters in range                                             ---
# 341      7.18     4.69     52.9     2000 All parameters in range                                             ---
# 342      7.18     4.69     52.6     2000 All parameters in range                                             ---
# 343      7.18     4.69     52.3     2000 All parameters in range                                             ---
# 344      7.17     4.68     52.0     2000 All parameters in range                                             ---
# 345      7.17     4.68     51.7     2000 All parameters in range                                             ---
# 346      7.17     4.68     51.4     2000 All parameters in range                                             ---
# 347      7.17     4.68     51.1     2000 All parameters in range                                             ---
# 348      7.17     4.68     50.8     2000 All parameters in range                                             ---
# 349      7.17     4.68     50.5     2000 All parameters in range                                             ---
# 350      7.17     4.68     50.2     2000 All parameters in range                                             ---
# 351      7.17     4.67     49.9     2000 DOSE URINE: TAN+EC LOW (TAN=49.9, EC=4.67) -> urine to TAN=125.0       50.0
# 352      7.20     4.71     53.3     2050 All parameters in range                                             ---
# 353      7.20     4.71     53.0     2050 All parameters in range                                             ---
# 354      7.19     4.71     52.7     2050 All parameters in range                                             ---
# 355      7.19     4.71     52.4     2050 All parameters in range                                             ---
# 356      7.19     4.70     52.1     2050 All parameters in range                                             ---
# 357      7.19     4.70     51.8     2050 All parameters in range                                             ---
# 358      7.19     4.70     51.5     2050 All parameters in range                                             ---
# 359      7.19     4.70     51.2     2050 All parameters in range                                             ---
# 360      7.19     4.70     50.9     2050 All parameters in range                                             ---
# 361      7.19     4.70     50.5     2050 All parameters in range                                             ---
# 362      7.18     4.70     50.2     2050 All parameters in range                                             ---
# 363      7.18     4.69     49.9     2050 DOSE URINE: TAN+EC LOW (TAN=49.9, EC=4.69) -> urine to TAN=125.0       50.0
# 364      7.21     4.73     53.2     2100 DOSE WINE: pH HIGH (7.21>7.2) -> dose to 7.0                       50.0
# 365      7.14     4.62     51.7     2150 All parameters in range                                             ---
# 366      7.14     4.62     51.4     2150 All parameters in range                                             ---
# 367      7.14     4.62     51.1     2150 All parameters in range                                             ---
# 368      7.13     4.61     50.8     2150 All parameters in range                                             ---
# 369      7.13     4.61     50.5     2150 All parameters in range                                             ---
# 370      7.13     4.61     50.2     2150 All parameters in range                                             ---
# 371      7.13     4.61     49.9     2150 DOSE URINE: TAN+EC LOW (TAN=49.9, EC=4.61) -> urine to TAN=125.0       50.0
# 372      7.16     4.65     53.0     2200 All parameters in range                                             ---
# 373      7.16     4.64     52.7     2200 All parameters in range                                             ---
# 374      7.16     4.64     52.4     2200 All parameters in range                                             ---
# 375      7.16     4.64     52.1     2200 All parameters in range                                             ---
# 376      7.16     4.64     51.8     2200 All parameters in range                                             ---
# 377      7.15     4.64     51.5     2200 All parameters in range                                             ---
# 378      7.15     4.64     51.2     2200 All parameters in range                                             ---
# 379      7.15     4.64     50.9     2200 All parameters in range                                             ---
# 380      7.15     4.63     50.6     2200 All parameters in range                                             ---
# 381      7.15     4.63     50.3     2200 All parameters in range                                             ---
# 382      7.15     4.63     50.0     2200 DOSE URINE: TAN+EC LOW (TAN=50.0, EC=4.63) -> urine to TAN=125.0       50.0
# 383      7.18     4.67     53.0     2250 All parameters in range                                             ---
# 384      7.18     4.66     52.7     2250 All parameters in range                                             ---
# 385      7.17     4.66     52.4     2250 All parameters in range                                             ---
# 386      7.17     4.66     52.1     2250 All parameters in range                                             ---
# 387      7.17     4.66     51.8     2250 All parameters in range                                             ---
# 388      7.17     4.66     51.5     2250 All parameters in range                                             ---
# 389      7.17     4.66     51.2     2250 All parameters in range                                             ---
# 390      7.17     4.66     50.9     2250 All parameters in range                                             ---
# 391      7.17     4.65     50.6     2250 All parameters in range                                             ---
# 392      7.17     4.65     50.3     2250 All parameters in range                                             ---
# 393      7.16     4.65     50.0     2250 DOSE URINE: TAN+EC LOW (TAN=50.0, EC=4.65) -> urine to TAN=125.0       50.0
# 394      7.19     4.68     52.9     2300 All parameters in range                                             ---
# 395      7.19     4.68     52.6     2300 All parameters in range                                             ---
# 396      7.19     4.68     52.3     2300 All parameters in range                                             ---
# 397      7.19     4.68     52.0     2300 All parameters in range                                             ---
# 398      7.19     4.68     51.7     2300 All parameters in range                                             ---
# 399      7.19     4.68     51.4     2300 All parameters in range                                             ---
# 400      7.19     4.68     51.1     2300 All parameters in range                                             ---
# 401      7.18     4.67     50.8     2300 All parameters in range                                             ---
# 402      7.18     4.67     50.5     2300 All parameters in range                                             ---
# 403      7.18     4.67     50.2     2300 All parameters in range                                             ---
# 404      7.18     4.67     49.9     2300 DOSE URINE: TAN+EC LOW (TAN=49.9, EC=4.67) -> urine to TAN=125.0       50.0
# 405      7.21     4.70     52.8     2350 DOSE WINE: pH HIGH (7.21>7.2) -> dose to 7.0                       50.0
# 406      7.14     4.60     51.4     2400 All parameters in range                                             ---
# 407      7.14     4.60     51.1     2400 All parameters in range                                             ---
# 408      7.14     4.60     50.8     2400 All parameters in range                                             ---
# 409      7.14     4.60     50.5     2400 All parameters in range                                             ---
# 410      7.13     4.60     50.2     2400 All parameters in range                                             ---
# 411      7.13     4.60     49.9     2400 DOSE URINE: TAN+EC LOW (TAN=49.9, EC=4.60) -> urine to TAN=125.0       50.0
# 412      7.16     4.63     52.7     2450 All parameters in range                                             ---
# 413      7.16     4.63     52.4     2450 All parameters in range                                             ---
# 414      7.16     4.63     52.1     2450 All parameters in range                                             ---
# 415      7.16     4.62     51.8     2450 All parameters in range                                             ---
# 416      7.16     4.62     51.5     2450 All parameters in range                                             ---
# 417      7.15     4.62     51.2     2450 All parameters in range                                             ---
# 418      7.15     4.62     50.9     2450 All parameters in range                                             ---
# 419      7.15     4.62     50.6     2450 All parameters in range                                             ---
# 420      7.15     4.62     50.3     2450 All parameters in range                                             ---
# 421      7.15     4.61     50.0     2450 DOSE URINE: TAN+EC LOW (TAN=50.0, EC=4.61) -> urine to TAN=125.0       50.0
# 422      7.17     4.65     52.7     2500 All parameters in range                                             ---
# 423      7.17     4.64     52.4     2500 All parameters in range                                             ---
# 424      7.17     4.64     52.1     2500 All parameters in range                                             ---
# 425      7.17     4.64     51.8     2500 All parameters in range                                             ---
# 426      7.17     4.64     51.5     2500 All parameters in range                                             ---
# 427      7.17     4.64     51.2     2500 All parameters in range                                             ---
# 428      7.17     4.64     50.8     2500 All parameters in range                                             ---
# 429      7.17     4.64     50.5     2500 All parameters in range                                             ---
# 430      7.17     4.63     50.2     2500 All parameters in range                                             ---
# 431      7.16     4.63     49.9     2500 DOSE URINE: TAN+EC LOW (TAN=49.9, EC=4.63) -> urine to TAN=125.0       50.0
# 432      7.19     4.66     52.6     2550 All parameters in range                                             ---
# 433      7.19     4.66     52.3     2550 All parameters in range                                             ---
# 434      7.19     4.66     52.0     2550 All parameters in range                                             ---
# 435      7.19     4.66     51.7     2550 All parameters in range                                             ---
# 436      7.18     4.66     51.4     2550 All parameters in range                                             ---
# 437      7.18     4.66     51.1     2550 All parameters in range                                             ---
# 438      7.18     4.65     50.8     2550 All parameters in range                                             ---
# 439      7.18     4.65     50.5     2550 All parameters in range                                             ---
# 440      7.18     4.65     50.2     2550 All parameters in range                                             ---
# 441      7.18     4.65     49.9     2550 DOSE URINE: TAN+EC LOW (TAN=49.9, EC=4.65) -> urine to TAN=125.0       50.0
# 442      7.20     4.68     52.5     2600 DOSE WINE: pH HIGH (7.20>7.2) -> dose to 7.0                       50.0
# 443      7.14     4.59     51.2     2650 All parameters in range                                             ---
# 444      7.14     4.59     50.9     2650 All parameters in range                                             ---
# 445      7.14     4.59     50.6     2650 All parameters in range                                             ---
# 446      7.14     4.59     50.3     2650 All parameters in range                                             ---
# 447      7.14     4.58     50.0     2650 DOSE URINE: TAN+EC LOW (TAN=50.0, EC=4.58) -> urine to TAN=125.0       50.0
# 448      7.16     4.61     52.4     2700 All parameters in range                                             ---
# 449      7.16     4.61     52.1     2700 All parameters in range                                             ---
# 450      7.16     4.61     51.8     2700 All parameters in range                                             ---
# 451      7.16     4.61     51.5     2700 All parameters in range                                             ---
# 452      7.15     4.61     51.2     2700 All parameters in range                                             ---
# 453      7.15     4.61     50.9     2700 All parameters in range                                             ---
# 454      7.15     4.60     50.6     2700 All parameters in range                                             ---
# 455      7.15     4.60     50.3     2700 All parameters in range                                             ---
# 456      7.15     4.60     50.0     2700 All parameters in range                                             ---
# 457      7.15     4.60     49.7     2700 DOSE URINE: TAN+EC LOW (TAN=49.7, EC=4.60) -> urine to TAN=125.0       50.0
# 458      7.17     4.63     52.2     2750 All parameters in range                                             ---
# 459      7.17     4.63     51.9     2750 All parameters in range                                             ---
# 460      7.17     4.63     51.6     2750 All parameters in range                                             ---
# 461      7.17     4.62     51.3     2750 All parameters in range                                             ---
# 462      7.17     4.62     50.9     2750 All parameters in range                                             ---
# 463      7.17     4.62     50.6     2750 All parameters in range                                             ---
# 464      7.16     4.62     50.3     2750 All parameters in range                                             ---
# 465      7.16     4.62     50.0     2750 All parameters in range                                             ---
# 466      7.16     4.62     49.7     2750 DOSE URINE: TAN+EC LOW (TAN=49.7, EC=4.62) -> urine to TAN=125.0       50.0
# 467      7.19     4.64     52.1     2800 All parameters in range                                             ---
# 468      7.18     4.64     51.8     2800 All parameters in range                                             ---
# 469      7.18     4.64     51.5     2800 All parameters in range                                             ---
# 470      7.18     4.64     51.2     2800 All parameters in range                                             ---
# 471      7.18     4.64     50.9     2800 All parameters in range                                             ---
# 472      7.18     4.64     50.6     2800 All parameters in range                                             ---
# 473      7.18     4.64     50.3     2800 All parameters in range                                             ---
# 474      7.18     4.63     50.0     2800 All parameters in range                                             ---
# 475      7.18     4.63     49.7     2800 DOSE URINE: TAN+EC LOW (TAN=49.7, EC=4.63) -> urine to TAN=125.0       50.0
# 476      7.20     4.66     52.0     2850 All parameters in range                                             ---
# 477      7.20     4.66     51.7     2850 All parameters in range                                             ---
# 478      7.19     4.66     51.4     2850 All parameters in range                                             ---
# 479      7.19     4.66     51.1     2850 All parameters in range                                             ---
# 480      7.19     4.65     50.8     2850 All parameters in range                                             ---
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# ============================================================================================================================================
# SIMULATION SUMMARY
# ============================================================================================================================================
#
# Duration: 480 minutes (8.0 hours)
# Final Volume: 2850 mL
#
# Substrate Usage:
#   Wine        :    300.0 mL ( 16.2%) -   6 doses (avg 50.0 mL/dose)
#   Urine       :   1400.0 mL ( 75.7%) -  28 doses (avg 50.0 mL/dose)
#   Spirulina   :    150.0 mL (  8.1%) -   3 doses (avg 50.0 mL/dose)
#   Total       :   1850.0 mL - 37 doses
#
# Final State:
#   pH:  7.19 (target range: 6.8-7.2)
#   EC:  4.65 mS/cm (target range: 5.0-10.0)
#   TAN: 50.8 mg-N/L (target range: 50.0-200.0)
#
# Range Compliance:
#   pH:  ✓ IN RANGE
#   EC:  ✗ OUT OF RANGE
#   TAN: ✓ IN RANGE
#
# Final Trace Metals:
#   Fe: 0.4755 mg/L (target: 1.0-10.0) LOW
#   Zn: 0.0647 mg/L (target: 0.1-1.0) LOW
#   Cu: 0.0591 mg/L (target: 0.01-0.5) OK
#   Mn: 0.0445 mg/L (target: 0.1-1.0) LOW
#   Se: 0.0033 mg/L (target: 0.01-0.1) LOW
#   Ni: 0.0037 mg/L (target: 0.05-1.0) LOW
#   Co: 0.0032 mg/L (target: 0.01-0.3) LOW
#
# ============================================================================================================================================
# COMPARISON: MPC vs BANG-BANG (fixed 5mL)
# ============================================================================================================================================
#   Metric                                MPC       Bang-Bang      Difference
#   ------------------------- --------------- --------------- ---------------
#   Total doses                            37             333            -296
#   Total volume (mL)                  1850.0            1665          +185.0
#   Avg dose size (mL)                   50.0             5.0
