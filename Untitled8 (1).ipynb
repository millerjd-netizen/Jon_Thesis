# %%
"""
MFC Bang-Bang Control Simulation (Baseline)
============================================
Fixed 5mL doses, threshold-based control

- Fixed DOSE_VOLUME = 5.0 mL every time
- Doses when threshold crossed (not to setpoint)
- Evaluates every 1 minute
- Priority: pH > TAN > EC
"""

import numpy as np

# =============================================================================
# SYSTEM PARAMETERS
# =============================================================================

V_INITIAL = 1000.0  # mL
DT = 1.0            # 1 minute timestep

# Fixed dose volume (bang-bang)
DOSE_VOLUME = 5.0   # mL per dose

# =============================================================================
# TARGET SETPOINTS
# =============================================================================

TARGETS = {
    'pH':  {'min': 6.8, 'max': 7.2, 'setpoint': 7.0},
    'EC':  {'min': 5.0, 'max': 10.0, 'setpoint': 7.5},
    'TAN': {'min': 50.0, 'max': 200.0, 'setpoint': 125.0}
}

METAL_TARGETS = {
    'Fe': (1.0, 10.0),
    'Zn': (0.1, 1.0),
    'Cu': (0.01, 0.5),
    'Mn': (0.1, 1.0),
    'Se': (0.01, 0.1),
    'Ni': (0.05, 1.0),
    'Co': (0.01, 0.3)
}

# =============================================================================
# AUTONOMOUS DYNAMICS (A matrix diagonal + drift d)
# =============================================================================

A_PH  = -0.0001    # per minute
A_EC  = -0.0001    # per minute
A_TAN = -0.00003   # per minute

D_PH  = -0.0005    # pH/min (CO2/VFA production)
D_EC  = -0.001     # mS/cm/min (ion uptake)
D_TAN = -0.3       # mg-N/L/min (bacterial consumption)

METAL_DECAY_RATE = 0.0005  # per minute

# =============================================================================
# SUBSTRATE PROPERTIES
# =============================================================================

SUBSTRATES = {
    'wine': {
        'pH': 4.0, 'EC': 0.02, 'TAN': 0.1,
        'Fe': 0.05, 'Zn': 0.01, 'Cu': 0.001, 'Mn': 0.02,
        'Se': 0.0, 'Ni': 0.0, 'Co': 0.0
    },
    'urine': {
        'pH': 8.5, 'EC': 6.25, 'TAN': 200.0,
        'Fe': 0.01, 'Zn': 0.05, 'Cu': 0.01, 'Mn': 0.005,
        'Se': 0.001, 'Ni': 0.002, 'Co': 0.001
    },
    'spirulina': {
        'pH': 9.0, 'EC': 1.14, 'TAN': 144.0,
        'Fe': 4.275, 'Zn': 0.300, 'Cu': 0.915, 'Mn': 0.285,
        'Se': 0.00105, 'Ni': 0.0, 'Co': 0.0
    }
}

# =============================================================================
# CSTR MIXING: Apply dose
# =============================================================================

def apply_dose(state, volume, substrate_name, dose_ml):
    """
    Apply CSTR mixing physics when dosing a substrate.
    x_new = (x_reactor * V_reactor + x_substrate * V_dose) / (V_reactor + V_dose)
    """
    substrate = SUBSTRATES[substrate_name]
    new_vol = volume + dose_ml

    new_state = {}
    for key in state:
        if key in substrate:
            new_state[key] = (state[key] * volume + substrate[key] * dose_ml) / new_vol
        else:
            new_state[key] = state[key]

    return new_state, new_vol


# =============================================================================
# ODE DYNAMICS: Apply drift
# =============================================================================

def apply_drift(state, dt):
    """
    Apply autonomous dynamics (biological decay) over time step dt.
    dx/dt = Ax + d, integrated with forward Euler.
    """
    # State-dependent decay (Ax) + constant drift (d)
    dPH  = A_PH * state['pH'] + D_PH
    dEC  = A_EC * state['EC'] + D_EC
    dTAN = A_TAN * state['TAN'] + D_TAN

    # Euler integration
    new_pH  = state['pH'] + dPH * dt
    new_EC  = state['EC'] + dEC * dt
    new_TAN = state['TAN'] + dTAN * dt

    # Metal decay (first-order)
    decay_factor = np.exp(-METAL_DECAY_RATE * dt)

    return {
        'pH': max(0, new_pH),
        'EC': max(0.01, new_EC),
        'TAN': max(0, new_TAN),
        'Fe': state['Fe'] * decay_factor,
        'Zn': state['Zn'] * decay_factor,
        'Cu': state['Cu'] * decay_factor,
        'Mn': state['Mn'] * decay_factor,
        'Se': state['Se'] * decay_factor,
        'Ni': state['Ni'] * decay_factor,
        'Co': state['Co'] * decay_factor,
    }


# =============================================================================
# BANG-BANG CONTROL DECISION
# =============================================================================

def bangbang_control_decision(state):
    """
    Simple threshold-based bang-bang control.

    Priority: pH > TAN > EC

    Returns: (substrate_name or None, reason)
    """
    pH = state['pH']
    EC = state['EC']
    TAN = state['TAN']

    # === PRIORITY 1: pH control ===
    if pH > TARGETS['pH']['max']:
        return 'wine', f"pH HIGH ({pH:.2f}>{TARGETS['pH']['max']})"

    if pH < TARGETS['pH']['min']:
        return 'urine', f"pH LOW ({pH:.2f}<{TARGETS['pH']['min']})"

    # === PRIORITY 2 & 3: TAN and EC combined logic ===
    if TAN < TARGETS['TAN']['min'] and EC < TARGETS['EC']['min']:
        return 'urine', f"TAN+EC LOW (TAN={TAN:.1f}, EC={EC:.2f})"

    if TAN < TARGETS['TAN']['min']:
        return 'spirulina', f"TAN LOW ({TAN:.1f}<{TARGETS['TAN']['min']})"

    if EC < TARGETS['EC']['min']:
        return 'urine', f"EC LOW ({EC:.2f}<{TARGETS['EC']['min']})"

    # All in range
    return None, "All parameters in range"


# =============================================================================
# SIMULATION
# =============================================================================

def run_simulation(duration_minutes=480, initial_state=None):
    """Run the bang-bang simulation for specified duration."""

    if initial_state is None:
        initial_state = {
            'pH': 7.0, 'EC': 5.5, 'TAN': 80.0,
            'Fe': 1.0, 'Zn': 0.1, 'Cu': 0.05, 'Mn': 0.1,
            'Se': 0.01, 'Ni': 0.01, 'Co': 0.01
        }

    state = initial_state.copy()
    volume = V_INITIAL
    history = []

    # Tracking
    total_volumes = {'wine': 0.0, 'urine': 0.0, 'spirulina': 0.0}
    dose_counts = {'wine': 0, 'urine': 0, 'spirulina': 0}
    dose_events = []

    # Print header
    print("=" * 120)
    print("MFC BANG-BANG CONTROL SIMULATION (BASELINE)")
    print("Fixed 5mL doses, threshold-based control")
    print("=" * 120)
    print(f"\nTargets:")
    print(f"  pH:  {TARGETS['pH']['min']}-{TARGETS['pH']['max']}")
    print(f"  EC:  {TARGETS['EC']['min']}-{TARGETS['EC']['max']} mS/cm")
    print(f"  TAN: {TARGETS['TAN']['min']}-{TARGETS['TAN']['max']} mg-N/L")
    print(f"\nFixed dose: {DOSE_VOLUME} mL")
    print(f"Priority: pH > TAN > EC")
    print("\n" + "=" * 120)
    print(f"\n{'Time':<6} {'pH':>6} {'EC':>8} {'TAN':>8} {'Vol':>8} {'Action':<50} {'Dose':>8}")
    print(f"{'(min)':<6} {'':>6} {'(mS/cm)':>8} {'(mg-N/L)':>8} {'(mL)':>8} {'':<50} {'(mL)':>8}")
    print("-" * 120)

    for t in range(int(duration_minutes) + 1):
        # Store history
        history.append({'time': t, 'volume': volume, **state.copy()})

        # Bang-bang control decision
        action, reason = bangbang_control_decision(state)

        # Format output
        if action:
            action_str = f"DOSE {action.upper()}: {reason}"
            dose_str = f"{DOSE_VOLUME:.1f}"
        else:
            action_str = reason
            dose_str = "---"

        # Print status line
        print(f"{t:<6} {state['pH']:>6.2f} {state['EC']:>8.2f} {state['TAN']:>8.1f} "
              f"{volume:>8.0f} {action_str:<50} {dose_str:>8}")

        # Execute dose if needed
        if action:
            state, volume = apply_dose(state, volume, action, DOSE_VOLUME)
            dose_counts[action] += 1
            total_volumes[action] += DOSE_VOLUME
            dose_events.append({
                'time': t,
                'substrate': action,
                'volume_ml': DOSE_VOLUME,
                'reason': reason
            })

        # Apply drift for next timestep
        if t < duration_minutes:
            state = apply_drift(state, DT)

    # Print summary
    print("-" * 120)
    print("\n" + "=" * 120)
    print("SIMULATION SUMMARY")
    print("=" * 120)

    total_dosed = sum(total_volumes.values())
    print(f"\nDuration: {duration_minutes} minutes ({duration_minutes/60:.1f} hours)")
    print(f"Final Volume: {volume:.0f} mL")

    print(f"\nSubstrate Usage:")
    for sub in ['wine', 'urine', 'spirulina']:
        pct = (total_volumes[sub] / total_dosed * 100) if total_dosed > 0 else 0
        print(f"  {sub.capitalize():<12}: {total_volumes[sub]:>8.1f} mL ({pct:>5.1f}%) - "
              f"{dose_counts[sub]:>3} doses @ {DOSE_VOLUME} mL each")
    print(f"  {'Total':<12}: {total_dosed:>8.1f} mL - {sum(dose_counts.values())} doses")

    print(f"\nFinal State:")
    print(f"  pH:  {state['pH']:.2f} (target: {TARGETS['pH']['min']}-{TARGETS['pH']['max']})")
    print(f"  EC:  {state['EC']:.2f} mS/cm (target: {TARGETS['EC']['min']}-{TARGETS['EC']['max']})")
    print(f"  TAN: {state['TAN']:.1f} mg-N/L (target: {TARGETS['TAN']['min']}-{TARGETS['TAN']['max']})")

    # Range compliance
    ph_ok = TARGETS['pH']['min'] <= state['pH'] <= TARGETS['pH']['max']
    ec_ok = TARGETS['EC']['min'] <= state['EC'] <= TARGETS['EC']['max']
    tan_ok = TARGETS['TAN']['min'] <= state['TAN'] <= TARGETS['TAN']['max']

    print(f"\nRange Compliance:")
    print(f"  pH:  {'✓ IN RANGE' if ph_ok else '✗ OUT OF RANGE'}")
    print(f"  EC:  {'✓ IN RANGE' if ec_ok else '✗ OUT OF RANGE'}")
    print(f"  TAN: {'✓ IN RANGE' if tan_ok else '✗ OUT OF RANGE'}")

    print(f"\nFinal Trace Metals:")
    for metal, (lo, hi) in METAL_TARGETS.items():
        val = state[metal]
        status = "OK" if lo <= val <= hi else ("LOW" if val < lo else "HIGH")
        print(f"  {metal}: {val:.4f} mg/L (target: {lo}-{hi}) {status}")

    return history, dose_events


# =============================================================================
# MAIN
# =============================================================================

if __name__ == "__main__":
    history, events = run_simulation(duration_minutes=480)
# Out:
# ========================================================================================================================
# MFC BANG-BANG CONTROL SIMULATION (BASELINE)
# Fixed 5mL doses, threshold-based control
# ========================================================================================================================
#
# Targets:
#   pH:  6.8-7.2
#   EC:  5.0-10.0 mS/cm
#   TAN: 50.0-200.0 mg-N/L
#
# Fixed dose: 5.0 mL
# Priority: pH > TAN > EC
#
# ========================================================================================================================
#
# Time       pH       EC      TAN      Vol Action                                                 Dose
# (min)          (mS/cm) (mg-N/L)     (mL)                                                        (mL)
# ------------------------------------------------------------------------------------------------------------------------
# 0        7.00     5.50     80.0     1000 All parameters in range                                 ---
# 1        7.00     5.50     79.7     1000 All parameters in range                                 ---
# 2        7.00     5.50     79.4     1000 All parameters in range                                 ---
# 3        7.00     5.50     79.1     1000 All parameters in range                                 ---
# 4        7.00     5.49     78.8     1000 All parameters in range                                 ---
# 5        6.99     5.49     78.5     1000 All parameters in range                                 ---
# 6        6.99     5.49     78.2     1000 All parameters in range                                 ---
# 7        6.99     5.49     77.9     1000 All parameters in range                                 ---
# 8        6.99     5.49     77.6     1000 All parameters in range                                 ---
# 9        6.99     5.49     77.3     1000 All parameters in range                                 ---
# 10       6.99     5.48     77.0     1000 All parameters in range                                 ---
# 11       6.99     5.48     76.7     1000 All parameters in range                                 ---
# 12       6.99     5.48     76.4     1000 All parameters in range                                 ---
# 13       6.98     5.48     76.1     1000 All parameters in range                                 ---
# 14       6.98     5.48     75.8     1000 All parameters in range                                 ---
# 15       6.98     5.48     75.5     1000 All parameters in range                                 ---
# 16       6.98     5.48     75.2     1000 All parameters in range                                 ---
# 17       6.98     5.47     74.9     1000 All parameters in range                                 ---
# 18       6.98     5.47     74.6     1000 All parameters in range                                 ---
# 19       6.98     5.47     74.3     1000 All parameters in range                                 ---
# 20       6.98     5.47     74.0     1000 All parameters in range                                 ---
# 21       6.97     5.47     73.7     1000 All parameters in range                                 ---
# 22       6.97     5.47     73.3     1000 All parameters in range                                 ---
# 23       6.97     5.46     73.0     1000 All parameters in range                                 ---
# 24       6.97     5.46     72.7     1000 All parameters in range                                 ---
# 25       6.97     5.46     72.4     1000 All parameters in range                                 ---
# 26       6.97     5.46     72.1     1000 All parameters in range                                 ---
# 27       6.97     5.46     71.8     1000 All parameters in range                                 ---
# 28       6.97     5.46     71.5     1000 All parameters in range                                 ---
# 29       6.97     5.46     71.2     1000 All parameters in range                                 ---
# 30       6.96     5.45     70.9     1000 All parameters in range                                 ---
# 31       6.96     5.45     70.6     1000 All parameters in range                                 ---
# 32       6.96     5.45     70.3     1000 All parameters in range                                 ---
# 33       6.96     5.45     70.0     1000 All parameters in range                                 ---
# 34       6.96     5.45     69.7     1000 All parameters in range                                 ---
# 35       6.96     5.45     69.4     1000 All parameters in range                                 ---
# 36       6.96     5.44     69.1     1000 All parameters in range                                 ---
# 37       6.96     5.44     68.8     1000 All parameters in range                                 ---
# 38       6.95     5.44     68.5     1000 All parameters in range                                 ---
# 39       6.95     5.44     68.2     1000 All parameters in range                                 ---
# 40       6.95     5.44     67.9     1000 All parameters in range                                 ---
# 41       6.95     5.44     67.6     1000 All parameters in range                                 ---
# 42       6.95     5.44     67.3     1000 All parameters in range                                 ---
# 43       6.95     5.43     67.0     1000 All parameters in range                                 ---
# 44       6.95     5.43     66.7     1000 All parameters in range                                 ---
# 45       6.95     5.43     66.4     1000 All parameters in range                                 ---
# 46       6.94     5.43     66.1     1000 All parameters in range                                 ---
# 47       6.94     5.43     65.8     1000 All parameters in range                                 ---
# 48       6.94     5.43     65.5     1000 All parameters in range                                 ---
# 49       6.94     5.42     65.2     1000 All parameters in range                                 ---
# 50       6.94     5.42     64.9     1000 All parameters in range                                 ---
# 51       6.94     5.42     64.6     1000 All parameters in range                                 ---
# 52       6.94     5.42     64.3     1000 All parameters in range                                 ---
# 53       6.94     5.42     64.0     1000 All parameters in range                                 ---
# 54       6.94     5.42     63.7     1000 All parameters in range                                 ---
# 55       6.93     5.41     63.4     1000 All parameters in range                                 ---
# 56       6.93     5.41     63.1     1000 All parameters in range                                 ---
# 57       6.93     5.41     62.8     1000 All parameters in range                                 ---
# 58       6.93     5.41     62.5     1000 All parameters in range                                 ---
# 59       6.93     5.41     62.2     1000 All parameters in range                                 ---
# 60       6.93     5.41     61.9     1000 All parameters in range                                 ---
# 61       6.93     5.41     61.6     1000 All parameters in range                                 ---
# 62       6.93     5.40     61.3     1000 All parameters in range                                 ---
# 63       6.92     5.40     61.0     1000 All parameters in range                                 ---
# 64       6.92     5.40     60.7     1000 All parameters in range                                 ---
# 65       6.92     5.40     60.4     1000 All parameters in range                                 ---
# 66       6.92     5.40     60.1     1000 All parameters in range                                 ---
# 67       6.92     5.40     59.8     1000 All parameters in range                                 ---
# 68       6.92     5.39     59.5     1000 All parameters in range                                 ---
# 69       6.92     5.39     59.2     1000 All parameters in range                                 ---
# 70       6.92     5.39     58.9     1000 All parameters in range                                 ---
# 71       6.92     5.39     58.6     1000 All parameters in range                                 ---
# 72       6.91     5.39     58.3     1000 All parameters in range                                 ---
# 73       6.91     5.39     57.9     1000 All parameters in range                                 ---
# 74       6.91     5.39     57.6     1000 All parameters in range                                 ---
# 75       6.91     5.38     57.3     1000 All parameters in range                                 ---
# 76       6.91     5.38     57.0     1000 All parameters in range                                 ---
# 77       6.91     5.38     56.7     1000 All parameters in range                                 ---
# 78       6.91     5.38     56.4     1000 All parameters in range                                 ---
# 79       6.91     5.38     56.1     1000 All parameters in range                                 ---
# 80       6.90     5.38     55.8     1000 All parameters in range                                 ---
# 81       6.90     5.37     55.5     1000 All parameters in range                                 ---
# 82       6.90     5.37     55.2     1000 All parameters in range                                 ---
# 83       6.90     5.37     54.9     1000 All parameters in range                                 ---
# 84       6.90     5.37     54.6     1000 All parameters in range                                 ---
# 85       6.90     5.37     54.3     1000 All parameters in range                                 ---
# 86       6.90     5.37     54.0     1000 All parameters in range                                 ---
# 87       6.90     5.37     53.7     1000 All parameters in range                                 ---
# 88       6.89     5.36     53.4     1000 All parameters in range                                 ---
# 89       6.89     5.36     53.1     1000 All parameters in range                                 ---
# 90       6.89     5.36     52.8     1000 All parameters in range                                 ---
# 91       6.89     5.36     52.5     1000 All parameters in range                                 ---
# 92       6.89     5.36     52.2     1000 All parameters in range                                 ---
# 93       6.89     5.36     51.9     1000 All parameters in range                                 ---
# 94       6.89     5.35     51.6     1000 All parameters in range                                 ---
# 95       6.89     5.35     51.3     1000 All parameters in range                                 ---
# 96       6.89     5.35     51.0     1000 All parameters in range                                 ---
# 97       6.88     5.35     50.7     1000 All parameters in range                                 ---
# 98       6.88     5.35     50.4     1000 All parameters in range                                 ---
# 99       6.88     5.35     50.1     1000 All parameters in range                                 ---
# 100      6.88     5.35     49.8     1000 DOSE SPIRULINA: TAN LOW (49.8<50.0)                     5.0
# 101      6.89     5.32     50.0     1005 DOSE SPIRULINA: TAN LOW (50.0<50.0)                     5.0
# 102      6.90     5.30     50.1     1010 All parameters in range                                 ---
# 103      6.90     5.30     49.8     1010 DOSE SPIRULINA: TAN LOW (49.8<50.0)                     5.0
# 104      6.91     5.28     50.0     1015 DOSE SPIRULINA: TAN LOW (50.0<50.0)                     5.0
# 105      6.92     5.26     50.2     1020 All parameters in range                                 ---
# 106      6.92     5.25     49.9     1020 DOSE SPIRULINA: TAN LOW (49.9<50.0)                     5.0
# 107      6.92     5.23     50.0     1025 All parameters in range                                 ---
# 108      6.92     5.23     49.7     1025 DOSE SPIRULINA: TAN LOW (49.7<50.0)                     5.0
# 109      6.93     5.21     49.9     1030 DOSE SPIRULINA: TAN LOW (49.9<50.0)                     5.0
# 110      6.94     5.19     50.0     1035 All parameters in range                                 ---
# 111      6.94     5.19     49.7     1035 DOSE SPIRULINA: TAN LOW (49.7<50.0)                     5.0
# 112      6.95     5.17     49.9     1040 DOSE SPIRULINA: TAN LOW (49.9<50.0)                     5.0
# 113      6.96     5.15     50.0     1045 All parameters in range                                 ---
# 114      6.96     5.14     49.7     1045 DOSE SPIRULINA: TAN LOW (49.7<50.0)                     5.0
# 115      6.96     5.12     49.9     1050 DOSE SPIRULINA: TAN LOW (49.9<50.0)                     5.0
# 116      6.97     5.10     50.0     1055 All parameters in range                                 ---
# 117      6.97     5.10     49.7     1055 DOSE SPIRULINA: TAN LOW (49.7<50.0)                     5.0
# 118      6.98     5.08     49.9     1060 DOSE SPIRULINA: TAN LOW (49.9<50.0)                     5.0
# 119      6.99     5.06     50.0     1065 DOSE SPIRULINA: TAN LOW (50.0<50.0)                     5.0
# 120      7.00     5.04     50.1     1070 All parameters in range                                 ---
# 121      6.99     5.04     49.8     1070 DOSE SPIRULINA: TAN LOW (49.8<50.0)                     5.0
# 122      7.00     5.02     50.0     1075 DOSE SPIRULINA: TAN LOW (50.0<50.0)                     5.0
# 123      7.01     5.00     50.1     1080 All parameters in range                                 ---
# 124      7.01     5.00     49.8     1080 DOSE URINE: TAN+EC LOW (TAN=49.8, EC=5.00)              5.0
# 125      7.02     5.00     50.2     1085 All parameters in range                                 ---
# 126      7.01     5.00     49.9     1085 DOSE SPIRULINA: TAN LOW (49.9<50.0)                     5.0
# 127      7.02     4.98     50.0     1090 DOSE URINE: EC LOW (4.98<5.0)                           5.0
# 128      7.03     4.99     50.4     1095 DOSE URINE: EC LOW (4.99<5.0)                           5.0
# 129      7.03     4.99     50.8     1100 DOSE URINE: EC LOW (4.99<5.0)                           5.0
# 130      7.04     5.00     51.2     1105 DOSE URINE: EC LOW (5.00<5.0)                           5.0
# 131      7.04     5.00     51.5     1110 DOSE URINE: EC LOW (5.00<5.0)                           5.0
# 132      7.05     5.00     51.9     1115 All parameters in range                                 ---
# 133      7.05     5.00     51.6     1115 All parameters in range                                 ---
# 134      7.05     5.00     51.3     1115 All parameters in range                                 ---
# 135      7.05     5.00     51.0     1115 DOSE URINE: EC LOW (5.00<5.0)                           5.0
# 136      7.05     5.00     51.3     1120 All parameters in range                                 ---
# 137      7.05     5.00     51.0     1120 All parameters in range                                 ---
# 138      7.05     5.00     50.7     1120 All parameters in range                                 ---
# 139      7.05     5.00     50.4     1120 DOSE URINE: EC LOW (5.00<5.0)                           5.0
# 140      7.05     5.00     50.8     1125 All parameters in range                                 ---
# 141      7.05     5.00     50.5     1125 All parameters in range                                 ---
# 142      7.05     5.00     50.2     1125 DOSE URINE: EC LOW (5.00<5.0)                           5.0
# 143      7.06     5.00     50.6     1130 All parameters in range                                 ---
# 144      7.05     5.00     50.3     1130 All parameters in range                                 ---
# 145      7.05     5.00     50.0     1130 DOSE SPIRULINA: TAN LOW (50.0<50.0)                     5.0
# 146      7.06     4.98     50.1     1135 DOSE URINE: EC LOW (4.98<5.0)                           5.0
# 147      7.07     4.99     50.4     1140 DOSE URINE: EC LOW (4.99<5.0)                           5.0
# 148      7.07     4.99     50.8     1145 DOSE URINE: EC LOW (4.99<5.0)                           5.0
# 149      7.08     4.99     51.1     1150 DOSE URINE: EC LOW (4.99<5.0)                           5.0
# 150      7.08     5.00     51.5     1155 DOSE URINE: EC LOW (5.00<5.0)                           5.0
# 151      7.09     5.00     51.8     1160 All parameters in range                                 ---
# 152      7.08     5.00     51.5     1160 All parameters in range                                 ---
# 153      7.08     5.00     51.2     1160 DOSE URINE: EC LOW (5.00<5.0)                           5.0
# 154      7.09     5.00     51.5     1165 All parameters in range                                 ---
# 155      7.09     5.00     51.2     1165 All parameters in range                                 ---
# 156      7.09     5.00     50.9     1165 All parameters in range                                 ---
# 157      7.08     5.00     50.6     1165 DOSE URINE: EC LOW (5.00<5.0)                           5.0
# 158      7.09     5.00     51.0     1170 All parameters in range                                 ---
# 159      7.09     5.00     50.7     1170 All parameters in range                                 ---
# 160      7.09     5.00     50.4     1170 DOSE URINE: EC LOW (5.00<5.0)                           5.0
# 161      7.09     5.00     50.7     1175 All parameters in range                                 ---
# 162      7.09     5.00     50.4     1175 All parameters in range                                 ---
# 163      7.09     5.00     50.1     1175 All parameters in range                                 ---
# 164      7.09     5.00     49.8     1175 DOSE URINE: TAN+EC LOW (TAN=49.8, EC=5.00)              5.0
# 165      7.09     5.00     50.1     1180 All parameters in range                                 ---
# 166      7.09     5.00     49.8     1180 DOSE SPIRULINA: TAN LOW (49.8<50.0)                     5.0
# 167      7.10     4.98     49.9     1185 DOSE URINE: TAN+EC LOW (TAN=49.9, EC=4.98)              5.0
# 168      7.10     4.99     50.3     1190 DOSE URINE: EC LOW (4.99<5.0)                           5.0
# 169      7.11     4.99     50.6     1195 DOSE URINE: EC LOW (4.99<5.0)                           5.0
# 170      7.11     4.99     50.9     1200 DOSE URINE: EC LOW (4.99<5.0)                           5.0
# 171      7.12     5.00     51.2     1205 DOSE URINE: EC LOW (5.00<5.0)                           5.0
# 172      7.12     5.00     51.5     1210 All parameters in range                                 ---
# 173      7.12     5.00     51.2     1210 All parameters in range                                 ---
# 174      7.12     5.00     50.9     1210 DOSE URINE: EC LOW (5.00<5.0)                           5.0
# 175      7.12     5.00     51.2     1215 All parameters in range                                 ---
# 176      7.12     5.00     50.9     1215 All parameters in range                                 ---
# 177      7.12     5.00     50.6     1215 DOSE URINE: EC LOW (5.00<5.0)                           5.0
# 178      7.13     5.00     51.0     1220 All parameters in range                                 ---
# 179      7.12     5.00     50.7     1220 All parameters in range                                 ---
# 180      7.12     5.00     50.3     1220 All parameters in range                                 ---
# 181      7.12     5.00     50.0     1220 DOSE URINE: EC LOW (5.00<5.0)                           5.0
# 182      7.13     5.00     50.4     1225 All parameters in range                                 ---
# 183      7.12     5.00     50.1     1225 All parameters in range                                 ---
# 184      7.12     5.00     49.8     1225 DOSE URINE: TAN+EC LOW (TAN=49.8, EC=5.00)              5.0
# 185      7.13     5.00     50.1     1230 All parameters in range                                 ---
# 186      7.13     5.00     49.8     1230 DOSE SPIRULINA: TAN LOW (49.8<50.0)                     5.0
# 187      7.13     4.98     49.8     1235 DOSE URINE: TAN+EC LOW (TAN=49.8, EC=4.98)              5.0
# 188      7.14     4.99     50.1     1240 DOSE URINE: EC LOW (4.99<5.0)                           5.0
# 189      7.14     4.99     50.4     1245 DOSE URINE: EC LOW (4.99<5.0)                           5.0
# 190      7.15     5.00     50.7     1250 DOSE URINE: EC LOW (5.00<5.0)                           5.0
# 191      7.15     5.00     51.0     1255 DOSE URINE: EC LOW (5.00<5.0)                           5.0
# 192      7.15     5.00     51.3     1260 All parameters in range                                 ---
# 193      7.15     5.00     51.0     1260 All parameters in range                                 ---
# 194      7.15     5.00     50.7     1260 DOSE URINE: EC LOW (5.00<5.0)                           5.0
# 195      7.16     5.00     51.0     1265 All parameters in range                                 ---
# 196      7.15     5.00     50.7     1265 All parameters in range                                 ---
# 197      7.15     5.00     50.4     1265 DOSE URINE: EC LOW (5.00<5.0)                           5.0
# 198      7.16     5.00     50.7     1270 All parameters in range                                 ---
# 199      7.16     5.00     50.4     1270 All parameters in range                                 ---
# 200      7.16     5.00     50.1     1270 DOSE URINE: EC LOW (5.00<5.0)                           5.0
# 201      7.16     5.00     50.4     1275 All parameters in range                                 ---
# 202      7.16     5.00     50.1     1275 All parameters in range                                 ---
# 203      7.16     5.00     49.8     1275 DOSE SPIRULINA: TAN LOW (49.8<50.0)                     5.0
# 204      7.16     4.98     49.8     1280 DOSE URINE: TAN+EC LOW (TAN=49.8, EC=4.98)              5.0
# 205      7.17     4.99     50.1     1285 DOSE URINE: EC LOW (4.99<5.0)                           5.0
# 206      7.17     4.99     50.4     1290 DOSE URINE: EC LOW (4.99<5.0)                           5.0
# 207      7.17     4.99     50.7     1295 DOSE URINE: EC LOW (4.99<5.0)                           5.0
# 208      7.18     5.00     51.0     1300 DOSE URINE: EC LOW (5.00<5.0)                           5.0
# 209      7.18     5.00     51.2     1305 All parameters in range                                 ---
# 210      7.18     5.00     50.9     1305 DOSE URINE: EC LOW (5.00<5.0)                           5.0
# 211      7.19     5.00     51.2     1310 All parameters in range                                 ---
# 212      7.18     5.00     50.9     1310 All parameters in range                                 ---
# 213      7.18     5.00     50.6     1310 DOSE URINE: EC LOW (5.00<5.0)                           5.0
# 214      7.19     5.00     50.9     1315 All parameters in range                                 ---
# 215      7.19     5.00     50.6     1315 All parameters in range                                 ---
# 216      7.18     5.00     50.3     1315 DOSE URINE: EC LOW (5.00<5.0)                           5.0
# 217      7.19     5.00     50.5     1320 All parameters in range                                 ---
# 218      7.19     5.00     50.2     1320 All parameters in range                                 ---
# 219      7.19     5.00     49.9     1320 DOSE URINE: TAN+EC LOW (TAN=49.9, EC=5.00)              5.0
# 220      7.19     5.00     50.2     1325 All parameters in range                                 ---
# 221      7.19     5.00     49.9     1325 DOSE SPIRULINA: TAN LOW (49.9<50.0)                     5.0
# 222      7.19     4.99     49.9     1330 DOSE URINE: TAN+EC LOW (TAN=49.9, EC=4.99)              5.0
# 223      7.20     4.99     50.2     1335 DOSE URINE: EC LOW (4.99<5.0)                           5.0
# 224      7.20     4.99     50.4     1340 DOSE WINE: pH HIGH (7.20>7.2)                           5.0
# 225      7.19     4.97     50.0     1345 DOSE URINE: TAN+EC LOW (TAN=50.0, EC=4.97)              5.0
# 226      7.19     4.98     50.2     1350 DOSE URINE: EC LOW (4.98<5.0)                           5.0
# 227      7.19     4.98     50.5     1355 DOSE URINE: EC LOW (4.98<5.0)                           5.0
# 228      7.20     4.98     50.7     1360 DOSE URINE: EC LOW (4.98<5.0)                           5.0
# 229      7.20     4.98     51.0     1365 DOSE WINE: pH HIGH (7.20>7.2)                           5.0
#
DOSE WINE: pH HIGH (7.20>7.2)                           5.0
# 433      7.19     4.78     49.9     2385 DOSE URINE: TAN+EC LOW (TAN=49.9, EC=4.78)              5.0
# 434      7.19     4.78     49.9     2390 DOSE URINE: TAN+EC LOW (TAN=49.9, EC=4.78)              5.0
# 435      7.20     4.78     49.9     2395 DOSE URINE: TAN+EC LOW (TAN=49.9, EC=4.78)              5.0
# 436      7.20     4.78     50.0     2400 DOSE URINE: TAN+EC LOW (TAN=50.0, EC=4.78)              5.0
# 437      7.20     4.78     50.0     2405 DOSE URINE: TAN+EC LOW (TAN=50.0, EC=4.78)              5.0
# 438      7.20     4.79     50.0     2410 DOSE WINE: pH HIGH (7.20>7.2)                           5.0
# 439      7.19     4.77     49.6     2415 DOSE URINE: TAN+EC LOW (TAN=49.6, EC=4.77)              5.0
# 440      7.19     4.78     49.6     2420 DOSE URINE: TAN+EC LOW (TAN=49.6, EC=4.78)              5.0
# 441      7.20     4.78     49.6     2425 DOSE URINE: TAN+EC LOW (TAN=49.6, EC=4.78)              5.0
# 442      7.20     4.78     49.6     2430 DOSE URINE: TAN+EC LOW (TAN=49.6, EC=4.78)              5.0
# 443      7.20     4.78     49.6     2435 DOSE URINE: TAN+EC LOW (TAN=49.6, EC=4.78)              5.0
# 444      7.20     4.78     49.6     2440 DOSE WINE: pH HIGH (7.20>7.2)                           5.0
# 445      7.19     4.77     49.2     2445 DOSE URINE: TAN+EC LOW (TAN=49.2, EC=4.77)              5.0
# 446      7.19     4.77     49.2     2450 DOSE URINE: TAN+EC LOW (TAN=49.2, EC=4.77)              5.0
# 447      7.20     4.77     49.2     2455 DOSE URINE: TAN+EC LOW (TAN=49.2, EC=4.77)              5.0
# 448      7.20     4.78     49.2     2460 DOSE URINE: TAN+EC LOW (TAN=49.2, EC=4.78)              5.0
# 449      7.20     4.78     49.2     2465 DOSE URINE: TAN+EC LOW (TAN=49.2, EC=4.78)              5.0
# 450      7.20     4.78     49.2     2470 DOSE URINE: TAN+EC LOW (TAN=49.2, EC=4.78)              5.0
# 451      7.20     4.78     49.2     2475 DOSE WINE: pH HIGH (7.20>7.2)                           5.0
# 452      7.19     4.77     48.8     2480 DOSE URINE: TAN+EC LOW (TAN=48.8, EC=4.77)              5.0
# 453      7.19     4.77     48.8     2485 DOSE URINE: TAN+EC LOW (TAN=48.8, EC=4.77)              5.0
# 454      7.20     4.77     48.8     2490 DOSE URINE: TAN+EC LOW (TAN=48.8, EC=4.77)              5.0
# 455      7.20     4.77     48.8     2495 DOSE URINE: TAN+EC LOW (TAN=48.8, EC=4.77)              5.0
# 456      7.20     4.78     48.8     2500 DOSE URINE: TAN+EC LOW (TAN=48.8, EC=4.78)              5.0
# 457      7.20     4.78     48.8     2505 DOSE WINE: pH HIGH (7.20>7.2)                           5.0
# 458      7.19     4.77     48.4     2510 DOSE URINE: TAN+EC LOW (TAN=48.4, EC=4.77)              5.0
# 459      7.19     4.77     48.4     2515 DOSE URINE: TAN+EC LOW (TAN=48.4, EC=4.77)              5.0
# 460      7.20     4.77     48.4     2520 DOSE URINE: TAN+EC LOW (TAN=48.4, EC=4.77)              5.0
# 461      7.20     4.77     48.4     2525 DOSE URINE: TAN+EC LOW (TAN=48.4, EC=4.77)              5.0
# 462      7.20     4.77     48.4     2530 DOSE URINE: TAN+EC LOW (TAN=48.4, EC=4.77)              5.0
# 463      7.20     4.77     48.4     2535 DOSE URINE: TAN+EC LOW (TAN=48.4, EC=4.77)              5.0
# 464      7.20     4.77     48.4     2540 DOSE WINE: pH HIGH (7.20>7.2)                           5.0
# 465      7.19     4.76     48.0     2545 DOSE URINE: TAN+EC LOW (TAN=48.0, EC=4.76)              5.0
# 466      7.19     4.76     48.0     2550 DOSE URINE: TAN+EC LOW (TAN=48.0, EC=4.76)              5.0
# 467      7.20     4.77     48.0     2555 DOSE URINE: TAN+EC LOW (TAN=48.0, EC=4.77)              5.0
# 468      7.20     4.77     48.0     2560 DOSE URINE: TAN+EC LOW (TAN=48.0, EC=4.77)              5.0
# 469      7.20     4.77     48.0     2565 DOSE URINE: TAN+EC LOW (TAN=48.0, EC=4.77)              5.0
# 470      7.20     4.77     48.0     2570 DOSE WINE: pH HIGH (7.20>7.2)                           5.0
# 471      7.19     4.76     47.6     2575 DOSE URINE: TAN+EC LOW (TAN=47.6, EC=4.76)              5.0
# 472      7.19     4.76     47.6     2580 DOSE URINE: TAN+EC LOW (TAN=47.6, EC=4.76)              5.0
# 473      7.20     4.76     47.6     2585 DOSE URINE: TAN+EC LOW (TAN=47.6, EC=4.76)              5.0
# 474      7.20     4.76     47.6     2590 DOSE URINE: TAN+EC LOW (TAN=47.6, EC=4.76)              5.0
# 475      7.20     4.77     47.6     2595 DOSE URINE: TAN+EC LOW (TAN=47.6, EC=4.77)              5.0
# 476      7.20     4.77     47.6     2600 DOSE URINE: TAN+EC LOW (TAN=47.6, EC=4.77)              5.0
# 477      7.20     4.77     47.6     2605 DOSE WINE: pH HIGH (7.20>7.2)                           5.0
# 478      7.19     4.76     47.2     2610 DOSE URINE: TAN+EC LOW (TAN=47.2, EC=4.76)              5.0
# 479      7.19     4.76     47.2     2615 DOSE URINE: TAN+EC LOW (TAN=47.2, EC=4.76)              5.0
# 480      7.20     4.76     47.2     2620 DOSE URINE: TAN+EC LOW (TAN=47.2, EC=4.76)              5.0
# ------------------------------------------------------------------------------------------------------------------------
#
# ========================================================================================================================
# SIMULATION SUMMARY
# ========================================================================================================================
#
# Duration: 480 minutes (8.0 hours)
# Final Volume: 2625 mL
#
# Substrate Usage:
#   Wine        :    235.0 mL ( 14.5%) -  47 doses @ 5.0 mL each
#   Urine       :   1280.0 mL ( 78.8%) - 256 doses @ 5.0 mL each
#   Spirulina   :    110.0 mL (  6.8%) -  22 doses @ 5.0 mL each
#   Total       :   1625.0 mL - 325 doses
#
# Final State:
#   pH:  7.20 (target: 6.8-7.2)
#   EC:  4.76 mS/cm (target: 5.0-10.0)
#   TAN: 47.5 mg-N/L (target: 50.0-200.0)
#
# Range Compliance:
#   pH:  ✓ IN RANGE
#   EC:  ✗ OUT OF RANGE
#   TAN: ✗ OUT OF RANGE
#
# Final Trace Metals:
#   Fe: 0.4587 mg/L (target: 1.0-10.0) LOW
#   Zn: 0.0639 mg/L (target: 0.1-1.0) LOW
#   Cu: 0.0517 mg/L (target: 0.01-0.5) OK
#   Mn: 0.0439 mg/L (target: 0.1-1.0) LOW
#   Se: 0.0035 mg/L (target: 0.01-0.1) LOW
#   Ni: 0.0039 mg/L (target: 0.05-1.0) LOW
#   Co: 0.0034 mg/L (target: 0.01-0.3) LOW
